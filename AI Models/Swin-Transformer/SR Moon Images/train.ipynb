# %%
import sys
sys.path.append('G:/My Drive/Moon Mapping/Models/Moon-Mapping/AI Models/Swin-Transformer/models')

from swin_transformer import SwinTransformerBlock
import torch

# %%
model = SwinTransformerBlock(180, (720, 720), 6, window_size=8, shift_size=4).to(device = 'cuda')
# Out:
# c:\Users\Sukhvansh Jain\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ..\aten\src\ATen\native\TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
tensor = torch.rand([1, 720**2, 180]).to(device='cuda')
print(model(tensor).shape)
# Out:
# torch.Size([1, 518400, 180])

# %%
print(tensor.shape)
# Out:
# torch.Size([1, 518400, 180])

# %%
convolution = torch.nn.Conv2d(in_channels = 180, out_channels=3, kernel_size = 3, padding = "same")
print(convolution(tensor.view(1,720,720,180)))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 2
#       1 convolution = torch.nn.Conv2d(in_channels = 180, out_channels=3, kernel_size = 3, padding = "same")
# ----> 2 print(convolution(tensor.view(1,720,720,180)))
#
# File c:\Users\Sukhvansh Jain\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
# ...
