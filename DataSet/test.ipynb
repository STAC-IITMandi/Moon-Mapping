# %%
from PIL import Image
import imageio
import numpy as np
import xml

# %%
#img = imageio.imread('ch2_ohr_nrp_20200229T0938004033_d_img_d32/browse/raw/20200229/ch2_ohr_nrp_20200229T0938004033_b_brw_d32.png')
img = Image.open('ch2_ohr_nrp_20200229T0938004033_d_img_d32/browse/raw/20200229/ch2_ohr_nrp_20200229T0938004033_b_brw_d32.png')
#print(img)
img = np.array(img)
print(img)
print(img.shape)
# Out:
# [[134 137 174 ... 194 199 183]
#  [176 155  53 ... 186 178 175]
#  [206 201 154 ... 207 173 173]
#  ...
#  [145 118  90 ... 103 142 129]
#  [106 117  61 ... 125  55 158]
#  [ 92 186 136 ... 113 130 105]]
# (9369, 1200)

# %%
f = open('ch2_ohr_nrp_20200229T0938004033_d_img_d32/miscellaneous/readme.txt','r')
file = f.read()
n = file.find("Latitude of OHRC payload trace")
print(file[n:n+len("Latitude of OHRC payload trace")])
# Out:
# Latitude of OHRC payload trace

# %%
f = open("DataSet/TMC/ch2_tmc_ndn_20230223T1106344149_d_oth_n18/data/derived/20230223/ch2_tmc_ndn_20230223T1106344149_d_oth_n18.xml",'r')
print(f.read())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# e:\ISRO PS-Transformer\test.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/ISRO%20PS-Transformer/test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> f = open("DataSet/TMC/ch2_tmc_ndn_20230223T1106344149_d_oth_n18/data/derived/20230223/ch2_tmc_ndn_20230223T1106344149_d_oth_n18.xml",'r')
#       <a href='vscode-notebook-cell:/e%3A/ISRO%20PS-Transformer/test.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> print(f.read())
#
# File c:\Users\Sukhvansh Jain\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
# ...
